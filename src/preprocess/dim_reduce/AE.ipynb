# %%
# %cd /Users/Kunal/Projects/TCH_CardiacSignals_F20/
# Out:
# /Users/kunal/Projects/TCH_CardiacSignals_F20

# %%
from numpy.random import seed
seed(1)
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow
tensorflow.random.set_seed(2)
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, InputLayer, Dropout, Conv1D, MaxPooling1D, BatchNormalization, UpSampling1D, Conv1DTranspose
from tensorflow.keras.models import Sequential, Model
from src.preprocess.dim_reduce.patient_split import *
from src.preprocess.heartbeat_split import heartbeat_split
from sklearn.model_selection import train_test_split

# %%
def read_in(file_index, normalized, train, ratio):
    """
    Reads in a file and can toggle between normalized and original files
    :param file_index: patient number as string
    :param normalized: binary that determines whether the files should be normalized or not
    :param train: int that determines whether or not we are reading in data to train the model or for encoding
    :param ratio: ratio to split the files into train and test
    :return: returns npy array of patient data across 4 leads
    """
    # filepath = os.path.join("Working_Data", "Normalized_Fixed_Dim_HBs_Idx" + file_index + ".npy")
    # filepath = os.path.join("Working_Data", "1000d", "Normalized_Fixed_Dim_HBs_Idx35.npy")
    filepath = "Working_Data/Training_Subset/Normalized/two_hbs/Normalized_Fixed_Dim_HBs_Idx" + str(file_index) + ".npy"

    if normalized == 1:
        if train == 1:
            normal_train, normal_test, abnormal = patient_split_train(filepath, ratio)
            # noise_factor = 0.5
            # noise_train = normal_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=normal_train.shape)
            return normal_train, normal_test
        elif train == 0:
            training, test, full = patient_split_all(filepath, ratio)
            return training, test, full
        elif train == 2:
            train_, test, full = patient_split_all(filepath, ratio)
            noise_factor = 0.5
            noise_train = train_ + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_.shape)
            return train_, noise_train, test, full
    else:
        data = np.load(os.path.join("Working_Data", "Fixed_Dim_HBs_Idx" + file_index + ".npy"))
        return data

# %%
def build_model(sig_shape, encode_size):
    """
    Builds a deterministic autoencoder model, returning both the encoder and decoder models
    :param sig_shape: shape of input signal
    :param encode_size: dimension that we want to reduce to
    :return: encoder, decoder models
    """
    encoder = Sequential()
    encoder.add(InputLayer(sig_shape))
    encoder.add(Flatten())
    encoder.add(Dense(200, activation='tanh', kernel_initializer='glorot_normal'))
    encoder.add(Dense(125, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(100, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(50, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(25, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(encode_size))

    # Decoder
    decoder = Sequential()
    decoder.add(InputLayer((encode_size,)))
    decoder.add(Dense(25, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(50, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(100, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(125, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(200, activation='tanh', kernel_initializer='glorot_normal'))
    decoder.add(Dense(np.prod(sig_shape), activation='linear'))
    decoder.add(Reshape(sig_shape))

    return encoder, decoder

# %%
def training_ae(num_epochs, reduced_dim, file_index):
    """
    Training function for deterministic autoencoder model, saves the encoded and reconstructed arrays
    :param num_epochs: number of epochs to use
    :param reduced_dim: goal dimension
    :param file_index: patient number
    :return: None
    """
    normal, abnormal, all = read_in(file_index, 1, 0, 0.3)
    normal_train = normal[:round(len(normal)*.85),:]
    normal_valid = normal[round(len(normal)*.85):,:]
    signal_shape = normal.shape[1:]
    batch_size = round(len(normal) * 0.1)

    encoder, decoder = build_model(signal_shape, reduced_dim)

    encode = encoder(Input(signal_shape))
    reconstruction = decoder(encode)

    inp = Input(signal_shape)
    encode = encoder(inp)
    reconstruction = decoder(encode)

    autoencoder = Model(inp, reconstruction)
    opt = keras.optimizers.Adam(learning_rate=0.0008)
    autoencoder.compile(optimizer=opt, loss='mse')

    early_stopping = EarlyStopping(patience=10, min_delta=0.0001, mode='min')
    autoencoder = autoencoder.fit(x=normal_train, y=normal_train, epochs=num_epochs, validation_data=(normal_valid, normal_valid), batch_size=batch_size, callbacks=early_stopping)

    plt.plot(autoencoder.history['loss'])
    plt.plot(autoencoder.history['val_loss'])
    plt.title('model loss patient' + str(file_index))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    # save out the model
    # filename = 'ae_patient_' + str(file_index) + '_dim' + str(reduced_dim) + '_model'
    # autoencoder.save(filename + '.h5')
    # print('Model saved for ' + 'patient ' + str(file_index))

    # using AE to encode other data
    # encoded = encoder.predict(all)
    # reconstruction = decoder.predict(encoded)

    # save reconstruction, encoded, and input if needed
    # reconstruction_save = os.path.join("Working_Data", "reconstructed_ae_" + str(reduced_dim) + "d_Idx" + str(file_index) + ".npy")
    # encoded_save = os.path.join("Working_Data", "reduced_ae_" + str(reduced_dim) + "d_Idx" + str(file_index) + ".npy")

    # reconstruction_save = "Working_Data/Training_Subset/Model_Output/reconstructed_2hb_" + str(file_index) + ".npy"
    # encoded_save = "Working_Data/Training_Subset/Model_Output/encoded_2hb_" + str(file_index) + ".npy"
    #
    # np.save(reconstruction_save, reconstruction)
    # np.save(encoded_save,encoded)

    # if training and need to save test split for MSE calculation
    # input_save = os.path.join("Working_Data","1000d", "original_data_test_ae" + str(100) + "d_Idx" + str(35) + ".npy")
    # np.save(input_save, test)

# %%
def run(num_epochs, encoded_dim):
    """
    Run training autoencoder over all dims in list
    :param num_epochs: number of epochs to train for
    :param encoded_dim: dimension to run on
    :return None, saves arrays for reconstructed and dim reduced arrays
    """
    for patient_ in [1,16,4,11]: #heartbeat_split.indicies:
        print("Starting on index: " + str(patient_))
        training_ae(num_epochs, encoded_dim, patient_)
        print("Completed " + str(patient_) + " reconstruction and encoding, saved test data to assess performance")

# %%
#################### Training to be done for 100 epochs for all dimensions ############################################
run(100, 1)

# run(100,100)
# Out:
# Starting on index: 1
# Epoch 1/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.9326 - val_loss: 0.6699
# Epoch 2/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4018 - val_loss: 0.2913
# Epoch 3/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1563 - val_loss: 0.2558
# Epoch 4/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1263 - val_loss: 0.2331
# Epoch 5/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1104 - val_loss: 0.2261
# Epoch 6/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.1064 - val_loss: 0.2219
# Epoch 7/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1045 - val_loss: 0.2151
# Epoch 8/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1033 - val_loss: 0.2068
# Epoch 9/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.1026 - val_loss: 0.2008
# Epoch 10/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1023 - val_loss: 0.2032
# Epoch 11/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1021 - val_loss: 0.2018
# Epoch 12/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.1020 - val_loss: 0.2026
# Epoch 13/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.1019 - val_loss: 0.2014
# Epoch 14/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1019 - val_loss: 0.2015
# Epoch 15/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1019 - val_loss: 0.1997
# Epoch 16/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.1019 - val_loss: 0.2016
# Epoch 17/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1019 - val_loss: 0.2003
# Epoch 18/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1018 - val_loss: 0.2022
# Epoch 19/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1018 - val_loss: 0.2005
# Epoch 20/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1017 - val_loss: 0.2013
# Epoch 21/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1016 - val_loss: 0.2011
# Epoch 22/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1016 - val_loss: 0.2009
# Epoch 23/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1015 - val_loss: 0.2003
# Epoch 24/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1014 - val_loss: 0.2022
# Epoch 25/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1014 - val_loss: 0.1997
# Completed 1 reconstruction and encoding, saved test data to assess performance
# Starting on index: 16
# Epoch 1/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.9599 - val_loss: 0.8141
# Epoch 2/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6405 - val_loss: 0.3864
# Epoch 3/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2865 - val_loss: 0.1620
# Epoch 4/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1277 - val_loss: 0.0727
# Epoch 5/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0636 - val_loss: 0.0418
# Epoch 6/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0420 - val_loss: 0.0348
# Epoch 7/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0376 - val_loss: 0.0335
# Epoch 8/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0365 - val_loss: 0.0334
# Epoch 9/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0363 - val_loss: 0.0318
# Epoch 10/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0353 - val_loss: 0.0317
# Epoch 11/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0351 - val_loss: 0.0316
# Epoch 12/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0349 - val_loss: 0.0317
# Epoch 13/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0350 - val_loss: 0.0316
# Epoch 14/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0349 - val_loss: 0.0316
# Epoch 15/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0349 - val_loss: 0.0317
# Epoch 16/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0349 - val_loss: 0.0316
# Epoch 17/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0349 - val_loss: 0.0315
# Epoch 18/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0348 - val_loss: 0.0316
# Epoch 19/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0347 - val_loss: 0.0314
# Epoch 20/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0345 - val_loss: 0.0315
# Epoch 21/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0342 - val_loss: 0.0310
# Epoch 22/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0340 - val_loss: 0.0311
# Epoch 23/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0336 - val_loss: 0.0305
# Epoch 24/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0332 - val_loss: 0.0303
# Epoch 25/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0327 - val_loss: 0.0296
# Epoch 26/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0321 - val_loss: 0.0288
# Epoch 27/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0314 - val_loss: 0.0278
# Epoch 28/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0306 - val_loss: 0.0266
# Epoch 29/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0296 - val_loss: 0.0253
# Epoch 30/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0289 - val_loss: 0.0247
# Epoch 31/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0282 - val_loss: 0.0238
# Epoch 32/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0278 - val_loss: 0.0232
# Epoch 33/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0270 - val_loss: 0.0224
# Epoch 34/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0266 - val_loss: 0.0222
# Epoch 35/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0262 - val_loss: 0.0214
# Epoch 36/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0258 - val_loss: 0.0214
# Epoch 37/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0256 - val_loss: 0.0207
# Epoch 38/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0252 - val_loss: 0.0204
# Epoch 39/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0248 - val_loss: 0.0200
# Epoch 40/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0245 - val_loss: 0.0196
# Epoch 41/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0242 - val_loss: 0.0194
# Epoch 42/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0240 - val_loss: 0.0193
# Epoch 43/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0239 - val_loss: 0.0191
# Epoch 44/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0239 - val_loss: 0.0188
# Epoch 45/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0235 - val_loss: 0.0186
# Epoch 46/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0235 - val_loss: 0.0187
# Epoch 47/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0233 - val_loss: 0.0183
# Epoch 48/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0231 - val_loss: 0.0182
# Epoch 49/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0234 - val_loss: 0.0187
# Epoch 50/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0239 - val_loss: 0.0183
# Epoch 51/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0233 - val_loss: 0.0183
# Epoch 52/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0232 - val_loss: 0.0181
# Epoch 53/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0229 - val_loss: 0.0179
# Epoch 54/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0227 - val_loss: 0.0179
# Epoch 55/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0227 - val_loss: 0.0181
# Epoch 56/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0228 - val_loss: 0.0177
# Epoch 57/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0226 - val_loss: 0.0177
# Epoch 58/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0226 - val_loss: 0.0175
# Epoch 59/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0225 - val_loss: 0.0175
# Epoch 60/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0223 - val_loss: 0.0175
# Epoch 61/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0223 - val_loss: 0.0176
# Epoch 62/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0223 - val_loss: 0.0176
# Epoch 63/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0224 - val_loss: 0.0174
# Epoch 64/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0223 - val_loss: 0.0172
# Epoch 65/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0221 - val_loss: 0.0173
# Epoch 66/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0220 - val_loss: 0.0171
# Epoch 67/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0221 - val_loss: 0.0175
# Epoch 68/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0221 - val_loss: 0.0170
# Epoch 69/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0220 - val_loss: 0.0172
# Epoch 70/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0220 - val_loss: 0.0171
# Epoch 71/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0220 - val_loss: 0.0170
# Epoch 72/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0219 - val_loss: 0.0171
# Epoch 73/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0220 - val_loss: 0.0172
# Epoch 74/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0220 - val_loss: 0.0171
# Epoch 75/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0219 - val_loss: 0.0172
# Epoch 76/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0219 - val_loss: 0.0173
# Epoch 77/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0219 - val_loss: 0.0172
# Epoch 78/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0220 - val_loss: 0.0194
# Completed 16 reconstruction and encoding, saved test data to assess performance
# Starting on index: 4
# Epoch 1/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.9129 - val_loss: 0.6857
# Epoch 2/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.5382 - val_loss: 0.3977
# Epoch 3/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3556 - val_loss: 0.3283
# Epoch 4/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3029 - val_loss: 0.3152
# Epoch 5/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2920 - val_loss: 0.3180
# Epoch 6/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.2885 - val_loss: 0.3121
# Epoch 7/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.2800 - val_loss: 0.2939
# Epoch 8/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.2533 - val_loss: 0.2510
# Epoch 9/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.2125 - val_loss: 0.2103
# Epoch 10/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1751 - val_loss: 0.1824
# Epoch 11/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1518 - val_loss: 0.1689
# Epoch 12/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1466 - val_loss: 0.1727
# Epoch 13/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1463 - val_loss: 0.1683
# Epoch 14/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.1426 - val_loss: 0.1652
# Epoch 15/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1390 - val_loss: 0.1625
# Epoch 16/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1369 - val_loss: 0.1613
# Epoch 17/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.1360 - val_loss: 0.1603
# Epoch 18/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1356 - val_loss: 0.1601
# Epoch 19/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1355 - val_loss: 0.1611
# Epoch 20/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1353 - val_loss: 0.1598
# Epoch 21/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.1351 - val_loss: 0.1596
# Epoch 22/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1351 - val_loss: 0.1599
# Epoch 23/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.1351 - val_loss: 0.1594
# Epoch 24/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.1349 - val_loss: 0.1598
# Epoch 25/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1350 - val_loss: 0.1594
# Epoch 26/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.1348 - val_loss: 0.1602
# Epoch 27/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1347 - val_loss: 0.1597
# Epoch 28/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.1346 - val_loss: 0.1591
# Epoch 29/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.1346 - val_loss: 0.1590
# Epoch 30/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1346 - val_loss: 0.1594
# Epoch 31/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1345 - val_loss: 0.1591
# Epoch 32/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.1344 - val_loss: 0.1590
# Epoch 33/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1346 - val_loss: 0.1598
# Epoch 34/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1342 - val_loss: 0.1592
# Epoch 35/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1341 - val_loss: 0.1589
# Epoch 36/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.1340 - val_loss: 0.1612
# Epoch 37/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1350 - val_loss: 0.1590
# Epoch 38/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1328 - val_loss: 0.1560
# Epoch 39/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1292 - val_loss: 0.1512
# Epoch 40/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1211 - val_loss: 0.1386
# Epoch 41/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1180 - val_loss: 0.1366
# Epoch 42/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1155 - val_loss: 0.1343
# Epoch 43/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1012 - val_loss: 0.1198
# Epoch 44/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0959 - val_loss: 0.1091
# Epoch 45/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0818 - val_loss: 0.1056
# Epoch 46/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0807 - val_loss: 0.1025
# Epoch 47/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0776 - val_loss: 0.1001
# Epoch 48/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0762 - val_loss: 0.1024
# Epoch 49/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0793 - val_loss: 0.1031
# Epoch 50/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0751 - val_loss: 0.0902
# Epoch 51/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0634 - val_loss: 0.0868
# Epoch 52/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0612 - val_loss: 0.0844
# Epoch 53/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0597 - val_loss: 0.0845
# Epoch 54/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0608 - val_loss: 0.0874
# Epoch 55/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0603 - val_loss: 0.0839
# Epoch 56/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0583 - val_loss: 0.0830
# Epoch 57/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0576 - val_loss: 0.0793
# Epoch 58/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0544 - val_loss: 0.0766
# Epoch 59/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0533 - val_loss: 0.0779
# Epoch 60/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0512 - val_loss: 0.0762
# Epoch 61/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0505 - val_loss: 0.0755
# Epoch 62/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0510 - val_loss: 0.0760
# Epoch 63/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0512 - val_loss: 0.0759
# Epoch 64/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0514 - val_loss: 0.0761
# Epoch 65/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0521 - val_loss: 0.0757
# Epoch 66/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0547 - val_loss: 0.0815
# Epoch 67/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0558 - val_loss: 0.0772
# Epoch 68/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0513 - val_loss: 0.0766
# Epoch 69/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0513 - val_loss: 0.0756
# Epoch 70/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0508 - val_loss: 0.0750
# Epoch 71/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0497 - val_loss: 0.0748
# Epoch 72/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0505 - val_loss: 0.0766
# Epoch 73/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0511 - val_loss: 0.0773
# Epoch 74/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0495 - val_loss: 0.0761
# Epoch 75/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0497 - val_loss: 0.0765
# Epoch 76/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0489 - val_loss: 0.0737
# Epoch 77/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0481 - val_loss: 0.0743
# Epoch 78/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0476 - val_loss: 0.0733
# Epoch 79/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0473 - val_loss: 0.0730
# Epoch 80/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0471 - val_loss: 0.0727
# Epoch 81/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0474 - val_loss: 0.0731
# Epoch 82/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0477 - val_loss: 0.0728
# Epoch 83/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0478 - val_loss: 0.0730
# Epoch 84/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0473 - val_loss: 0.0730
# Epoch 85/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0470 - val_loss: 0.0734
# Epoch 86/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0470 - val_loss: 0.0729
# Epoch 87/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0486 - val_loss: 0.0759
# Epoch 88/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0502 - val_loss: 0.0726
# Epoch 89/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0478 - val_loss: 0.0723
# Epoch 90/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0477 - val_loss: 0.0732
# Epoch 91/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0474 - val_loss: 0.0725
# Epoch 92/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0475 - val_loss: 0.0723
# Epoch 93/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0480 - val_loss: 0.0744
# Epoch 94/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0475 - val_loss: 0.0736
# Epoch 95/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0476 - val_loss: 0.0742
# Epoch 96/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0464 - val_loss: 0.0715
# Epoch 97/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0466 - val_loss: 0.0733
# Epoch 98/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0473 - val_loss: 0.0723
# Epoch 99/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0479 - val_loss: 0.0734
# Epoch 100/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0482 - val_loss: 0.0740
# Completed 4 reconstruction and encoding, saved test data to assess performance
# Starting on index: 11
# Epoch 1/100
# 9/9 [==============================] - 0s 49ms/step - loss: 0.9582 - val_loss: 0.8301
# Epoch 2/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.5660 - val_loss: 0.5324
# Epoch 3/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2253 - val_loss: 0.4248
# Epoch 4/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1534 - val_loss: 0.4131
# Epoch 5/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.1209 - val_loss: 0.3888
# Epoch 6/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0997 - val_loss: 0.3776
# Epoch 7/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0860 - val_loss: 0.3726
# Epoch 8/100
#  - ETA: 0s - loss: 0.0742
# Epoch 9/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0777 - val_loss: 0.3683
# Epoch 10/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0766 - val_loss: 0.3678
# Epoch 11/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0761 - val_loss: 0.3667
# Epoch 12/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0759 - val_loss: 0.3663
# Epoch 13/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0757 - val_loss: 0.3658
# Epoch 14/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0756 - val_loss: 0.3654
# Epoch 15/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0754 - val_loss: 0.3644
# Epoch 16/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0753 - val_loss: 0.3648
# Epoch 17/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0751 - val_loss: 0.3649
# Epoch 18/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0750 - val_loss: 0.3636
# Epoch 19/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0748 - val_loss: 0.3629
# Epoch 20/100
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0746 - val_loss: 0.3631
# Epoch 21/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0744 - val_loss: 0.3629
# Epoch 22/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0742 - val_loss: 0.3630
# Epoch 23/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0739 - val_loss: 0.3610
# Epoch 24/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0737 - val_loss: 0.3623
# Epoch 25/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0734 - val_loss: 0.3594
# Epoch 26/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0731 - val_loss: 0.3606
# Epoch 27/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0728 - val_loss: 0.3605
# Epoch 28/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0725 - val_loss: 0.3585
# Epoch 29/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0722 - val_loss: 0.3590
# Epoch 30/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0718 - val_loss: 0.3591
# Epoch 31/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0715 - val_loss: 0.3609
# Epoch 32/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0711 - val_loss: 0.3598
# Epoch 33/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0708 - val_loss: 0.3612
# Epoch 34/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0705 - val_loss: 0.3635
# Epoch 35/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0702 - val_loss: 0.3655
# Epoch 36/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0700 - val_loss: 0.3664
# Epoch 37/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0698 - val_loss: 0.3662
# Epoch 38/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0694 - val_loss: 0.3695
# Completed 11 reconstruction and encoding, saved test data to assess performance
