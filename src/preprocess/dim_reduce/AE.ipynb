# %%
# %cd /Users/Kunal/Projects/TCH_CardiacSignals_F20/
# Out:
# /Users/kunal/Projects/TCH_CardiacSignals_F20

# %%
from numpy.random import seed
seed(1)
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow
tensorflow.random.set_seed(2)
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, InputLayer, Dropout, Conv1D, MaxPooling1D, BatchNormalization, UpSampling1D, Conv1DTranspose
from tensorflow.keras.models import Sequential, Model
from src.preprocess.dim_reduce.patient_split import *
from src.preprocess.heartbeat_split import heartbeat_split
from sklearn.model_selection import train_test_split

# %%
def read_in(file_index, normalized, train, ratio):
    """
    Reads in a file and can toggle between normalized and original files
    :param file_index: patient number as string
    :param normalized: binary that determines whether the files should be normalized or not
    :param train: int that determines whether or not we are reading in data to train the model or for encoding
    :param ratio: ratio to split the files into train and test
    :return: returns npy array of patient data across 4 leads
    """
    # filepath = os.path.join("Working_Data", "Normalized_Fixed_Dim_HBs_Idx" + file_index + ".npy")
    # filepath = os.path.join("Working_Data", "1000d", "Normalized_Fixed_Dim_HBs_Idx35.npy")
    filepath = "Working_Data/Training_Subset/Normalized/two_hbs/Normalized_Fixed_Dim_HBs_Idx" + str(file_index) + ".npy"

    if normalized == 1:
        if train == 1:
            normal_train, normal_test, abnormal = patient_split_train(filepath, ratio)
            # noise_factor = 0.5
            # noise_train = normal_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=normal_train.shape)
            return normal_train, normal_test
        elif train == 0:
            training, test, full = patient_split_all(filepath, ratio)
            return training, test, full
        elif train == 2:
            train_, test, full = patient_split_all(filepath, ratio)
            noise_factor = 0.5
            noise_train = train_ + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_.shape)
            return train_, noise_train, test, full
    else:
        data = np.load(os.path.join("Working_Data", "Fixed_Dim_HBs_Idx" + file_index + ".npy"))
        return data

# %%
def build_model(sig_shape, encode_size):
    """
    Builds a deterministic autoencoder model, returning both the encoder and decoder models
    :param sig_shape: shape of input signal
    :param encode_size: dimension that we want to reduce to
    :return: encoder, decoder models
    """
    encoder = Sequential()
    encoder.add(InputLayer(sig_shape))
    encoder.add(Flatten())
    encoder.add(Dense(200, activation='tanh', kernel_initializer='glorot_normal'))
    encoder.add(Dense(125, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(100, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(50, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(25, activation='relu', kernel_initializer='glorot_normal'))
    encoder.add(Dense(encode_size))

    # Decoder
    decoder = Sequential()
    decoder.add(InputLayer((encode_size,)))
    decoder.add(Dense(25, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(50, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(100, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(125, activation='relu', kernel_initializer='glorot_normal'))
    decoder.add(Dense(200, activation='tanh', kernel_initializer='glorot_normal'))
    decoder.add(Dense(np.prod(sig_shape), activation='linear'))
    decoder.add(Reshape(sig_shape))

    return encoder, decoder

# %%
def training_ae(num_epochs, reduced_dim, file_index):
    """
    Training function for deterministic autoencoder model, saves the encoded and reconstructed arrays
    :param num_epochs: number of epochs to use
    :param reduced_dim: goal dimension
    :param file_index: patient number
    :return: None
    """
    normal, abnormal, all = read_in(file_index, 1, 0, 0.3)
    normal_train = normal[:round(len(normal)*.85),:]
    normal_valid = normal[round(len(normal)*.85):,:]
    signal_shape = normal.shape[1:]
    batch_size = round(len(normal) * 0.1)

    encoder, decoder = build_model(signal_shape, reduced_dim)

    encode = encoder(Input(signal_shape))
    reconstruction = decoder(encode)

    inp = Input(signal_shape)
    encode = encoder(inp)
    reconstruction = decoder(encode)

    autoencoder = Model(inp, reconstruction)
    opt = keras.optimizers.Adam(learning_rate=0.0008)
    autoencoder.compile(optimizer=opt, loss='mse')

    early_stopping = EarlyStopping(patience=10, min_delta=0.0001, mode='min')
    autoencoder = autoencoder.fit(x=normal_train, y=normal_train, epochs=num_epochs, validation_data=(normal_valid, normal_valid), batch_size=batch_size, callbacks=early_stopping)

    plt.plot(autoencoder.history['loss'])
    plt.plot(autoencoder.history['val_loss'])
    plt.title('model loss patient' + str(file_index))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    # save out the model
    # filename = 'ae_patient_' + str(file_index) + '_dim' + str(reduced_dim) + '_model'
    # autoencoder.save(filename + '.h5')
    # print('Model saved for ' + 'patient ' + str(file_index))

    # using AE to encode other data
    encoded = encoder.predict(all)
    reconstruction = decoder.predict(encoded)

    # save reconstruction, encoded, and input if needed
    # reconstruction_save = os.path.join("Working_Data", "reconstructed_ae_" + str(reduced_dim) + "d_Idx" + str(file_index) + ".npy")
    # encoded_save = os.path.join("Working_Data", "reduced_ae_" + str(reduced_dim) + "d_Idx" + str(file_index) + ".npy")

    reconstruction_save = "Working_Data/Training_Subset/Model_Output/reconstructed_2hb_ae_" + str(file_index) + ".npy"
    encoded_save = "Working_Data/Training_Subset/Model_Output/encoded_2hb_ae_" + str(file_index) + ".npy"

    np.save(reconstruction_save, reconstruction)
    np.save(encoded_save,encoded)

    # if training and need to save test split for MSE calculation
    # input_save = os.path.join("Working_Data","1000d", "original_data_test_ae" + str(100) + "d_Idx" + str(35) + ".npy")
    # np.save(input_save, test)

# %%
def run(num_epochs, encoded_dim):
    """
    Run training autoencoder over all dims in list
    :param num_epochs: number of epochs to train for
    :param encoded_dim: dimension to run on
    :return None, saves arrays for reconstructed and dim reduced arrays
    """
    for patient_ in [1,16,4,11]: #heartbeat_split.indicies:
        print("Starting on index: " + str(patient_))
        training_ae(num_epochs, encoded_dim, patient_)
        print("Completed " + str(patient_) + " reconstruction and encoding, saved test data to assess performance")

# %%
#################### Training to be done for 100 epochs for all dimensions ############################################
run(100, 10)

# run(100,100)
# Out:
# Starting on index: 1
# Epoch 1/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.8349 - val_loss: 0.4565
# Epoch 2/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2817 - val_loss: 0.2523
# Epoch 3/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1434 - val_loss: 0.2509
# Epoch 4/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1153 - val_loss: 0.2298
# Epoch 5/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1082 - val_loss: 0.2260
# Epoch 6/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.1051 - val_loss: 0.2187
# Epoch 7/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1035 - val_loss: 0.2113
# Epoch 8/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1026 - val_loss: 0.2056
# Epoch 9/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1022 - val_loss: 0.2044
# Epoch 10/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1019 - val_loss: 0.2043
# Epoch 11/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1015 - val_loss: 0.2036
# Epoch 12/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1003 - val_loss: 0.2020
# Epoch 13/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0950 - val_loss: 0.1888
# Epoch 14/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0816 - val_loss: 0.1731
# Epoch 15/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0679 - val_loss: 0.1597
# Epoch 16/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0625 - val_loss: 0.1564
# Epoch 17/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0610 - val_loss: 0.1558
# Epoch 18/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0595 - val_loss: 0.1548
# Epoch 19/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0581 - val_loss: 0.1556
# Epoch 20/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0560 - val_loss: 0.1573
# Epoch 21/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0528 - val_loss: 0.1602
# Epoch 22/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0499 - val_loss: 0.1591
# Epoch 23/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0459 - val_loss: 0.1585
# Epoch 24/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0431 - val_loss: 0.1561
# Epoch 25/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0412 - val_loss: 0.1577
# Epoch 26/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0419 - val_loss: 0.1523
# Epoch 27/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0390 - val_loss: 0.1526
# Epoch 28/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0377 - val_loss: 0.1510
# Epoch 29/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0367 - val_loss: 0.1502
# Epoch 30/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0358 - val_loss: 0.1471
# Epoch 31/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0350 - val_loss: 0.1453
# Epoch 32/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0345 - val_loss: 0.1455
# Epoch 33/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0340 - val_loss: 0.1421
# Epoch 34/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0330 - val_loss: 0.1391
# Epoch 35/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0324 - val_loss: 0.1360
# Epoch 36/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0318 - val_loss: 0.1344
# Epoch 37/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0313 - val_loss: 0.1323
# Epoch 38/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0313 - val_loss: 0.1311
# Epoch 39/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0307 - val_loss: 0.1289
# Epoch 40/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0301 - val_loss: 0.1278
# Epoch 41/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0297 - val_loss: 0.1276
# Epoch 42/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0304 - val_loss: 0.1282
# Epoch 43/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0295 - val_loss: 0.1282
# Epoch 44/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0289 - val_loss: 0.1269
# Epoch 45/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0283 - val_loss: 0.1278
# Epoch 46/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0280 - val_loss: 0.1249
# Epoch 47/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0278 - val_loss: 0.1238
# Epoch 48/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0274 - val_loss: 0.1224
# Epoch 49/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0269 - val_loss: 0.1217
# Epoch 50/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0268 - val_loss: 0.1208
# Epoch 51/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0265 - val_loss: 0.1212
# Epoch 52/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0261 - val_loss: 0.1200
# Epoch 53/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0256 - val_loss: 0.1207
# Epoch 54/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0255 - val_loss: 0.1235
# Epoch 55/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0251 - val_loss: 0.1206
# Epoch 56/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0247 - val_loss: 0.1208
# Epoch 57/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0247 - val_loss: 0.1197
# Epoch 58/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0242 - val_loss: 0.1216
# Epoch 59/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0238 - val_loss: 0.1216
# Epoch 60/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0238 - val_loss: 0.1234
# Epoch 61/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0237 - val_loss: 0.1203
# Epoch 62/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0235 - val_loss: 0.1221
# Epoch 63/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0232 - val_loss: 0.1228
# Epoch 64/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0228 - val_loss: 0.1218
# Epoch 65/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0225 - val_loss: 0.1224
# Epoch 66/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0220 - val_loss: 0.1236
# Epoch 67/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0217 - val_loss: 0.1254
# Completed 1 reconstruction and encoding, saved test data to assess performance
# Starting on index: 16
# Epoch 1/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.9154 - val_loss: 0.7378
# Epoch 2/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5697 - val_loss: 0.4079
# Epoch 3/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3282 - val_loss: 0.2064
# Epoch 4/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.1740 - val_loss: 0.1032
# Epoch 5/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0906 - val_loss: 0.0548
# Epoch 6/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0526 - val_loss: 0.0373
# Epoch 7/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0395 - val_loss: 0.0321
# Epoch 8/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0356 - val_loss: 0.0302
# Epoch 9/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0339 - val_loss: 0.0293
# Epoch 10/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0331 - val_loss: 0.0284
# Epoch 11/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0325 - val_loss: 0.0274
# Epoch 12/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0316 - val_loss: 0.0265
# Epoch 13/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0307 - val_loss: 0.0255
# Epoch 14/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0299 - val_loss: 0.0244
# Epoch 15/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0291 - val_loss: 0.0235
# Epoch 16/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0283 - val_loss: 0.0227
# Epoch 17/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0277 - val_loss: 0.0219
# Epoch 18/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0271 - val_loss: 0.0214
# Epoch 19/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0264 - val_loss: 0.0207
# Epoch 20/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0258 - val_loss: 0.0205
# Epoch 21/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0253 - val_loss: 0.0196
# Epoch 22/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0246 - val_loss: 0.0193
# Epoch 23/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0243 - val_loss: 0.0195
# Epoch 24/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0242 - val_loss: 0.0190
# Epoch 25/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0237 - val_loss: 0.0184
# Epoch 26/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0233 - val_loss: 0.0184
# Epoch 27/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0230 - val_loss: 0.0182
# Epoch 28/100
# 9/9 [==============================] - 0s 51ms/step - loss: 0.0228 - val_loss: 0.0180
# Epoch 29/100
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0227 - val_loss: 0.0178
# Epoch 30/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0224 - val_loss: 0.0177
# Epoch 31/100
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0223 - val_loss: 0.0177
# Epoch 32/100
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0224 - val_loss: 0.0176
# Epoch 33/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0221 - val_loss: 0.0176
# Epoch 34/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0220 - val_loss: 0.0176
# Epoch 35/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0220 - val_loss: 0.0172
# Epoch 36/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0218 - val_loss: 0.0173
# Epoch 37/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0217 - val_loss: 0.0171
# Epoch 38/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0216 - val_loss: 0.0172
# Epoch 39/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0214 - val_loss: 0.0170
# Epoch 40/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0213 - val_loss: 0.0170
# Epoch 41/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0213 - val_loss: 0.0172
# Epoch 42/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0212 - val_loss: 0.0174
# Epoch 43/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0211 - val_loss: 0.0170
# Epoch 44/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0210 - val_loss: 0.0168
# Epoch 45/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0208 - val_loss: 0.0169
# Epoch 46/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0207 - val_loss: 0.0168
# Epoch 47/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0205 - val_loss: 0.0169
# Epoch 48/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0214 - val_loss: 0.0183
# Epoch 49/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0210 - val_loss: 0.0168
# Epoch 50/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0205 - val_loss: 0.0171
# Epoch 51/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0201 - val_loss: 0.0168
# Epoch 52/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0197 - val_loss: 0.0166
# Epoch 53/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0195 - val_loss: 0.0165
# Epoch 54/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0192 - val_loss: 0.0166
# Epoch 55/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0190 - val_loss: 0.0164
# Epoch 56/100
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0188 - val_loss: 0.0162
# Epoch 57/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0186 - val_loss: 0.0163
# Epoch 58/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0185 - val_loss: 0.0161
# Epoch 59/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0183 - val_loss: 0.0161
# Epoch 60/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0182 - val_loss: 0.0159
# Epoch 61/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0182 - val_loss: 0.0168
# Epoch 62/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0184 - val_loss: 0.0164
# Epoch 63/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0180 - val_loss: 0.0159
# Epoch 64/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0178 - val_loss: 0.0159
# Epoch 65/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0177 - val_loss: 0.0159
# Epoch 66/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0175 - val_loss: 0.0157
# Epoch 67/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0173 - val_loss: 0.0160
# Epoch 68/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0173 - val_loss: 0.0157
# Epoch 69/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0171 - val_loss: 0.0155
# Epoch 70/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0169 - val_loss: 0.0154
# Epoch 71/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0168 - val_loss: 0.0154
# Epoch 72/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0171 - val_loss: 0.0154
# Epoch 73/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0167 - val_loss: 0.0154
# Epoch 74/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0164 - val_loss: 0.0153
# Epoch 75/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 76/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0161 - val_loss: 0.0150
# Epoch 77/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0160 - val_loss: 0.0151
# Epoch 78/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0160 - val_loss: 0.0150
# Epoch 79/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0161 - val_loss: 0.0149
# Epoch 80/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0158 - val_loss: 0.0149
# Epoch 81/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0157 - val_loss: 0.0149
# Epoch 82/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0154 - val_loss: 0.0147
# Epoch 83/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0153 - val_loss: 0.0147
# Epoch 84/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0152 - val_loss: 0.0155
# Epoch 85/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0159 - val_loss: 0.0151
# Epoch 86/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0152 - val_loss: 0.0146
# Epoch 87/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0149 - val_loss: 0.0143
# Epoch 88/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0146 - val_loss: 0.0142
# Epoch 89/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0144 - val_loss: 0.0141
# Epoch 90/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0143 - val_loss: 0.0148
# Epoch 91/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0143 - val_loss: 0.0140
# Epoch 92/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0139 - val_loss: 0.0141
# Epoch 93/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0138 - val_loss: 0.0140
# Epoch 94/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0136 - val_loss: 0.0140
# Epoch 95/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0136 - val_loss: 0.0139
# Epoch 96/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0134 - val_loss: 0.0139
# Epoch 97/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0133 - val_loss: 0.0138
# Epoch 98/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0132 - val_loss: 0.0139
# Epoch 99/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0132 - val_loss: 0.0138
# Epoch 100/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0130 - val_loss: 0.0137
# Completed 16 reconstruction and encoding, saved test data to assess performance
# Starting on index: 4
# Epoch 1/100
# 9/9 [==============================] - 0s 52ms/step - loss: 0.9344 - val_loss: 0.7269
# Epoch 2/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.5728 - val_loss: 0.4068
# Epoch 3/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3383 - val_loss: 0.2751
# Epoch 4/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2238 - val_loss: 0.1917
# Epoch 5/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.1441 - val_loss: 0.1312
# Epoch 6/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0870 - val_loss: 0.0941
# Epoch 7/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0602 - val_loss: 0.0810
# Epoch 8/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0515 - val_loss: 0.0754
# Epoch 9/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0488 - val_loss: 0.0729
# Epoch 10/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0471 - val_loss: 0.0711
# Epoch 11/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0462 - val_loss: 0.0708
# Epoch 12/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0460 - val_loss: 0.0708
# Epoch 13/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0458 - val_loss: 0.0707
# Epoch 14/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0455 - val_loss: 0.0707
# Epoch 15/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0462 - val_loss: 0.0719
# Epoch 16/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0458 - val_loss: 0.0707
# Epoch 17/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0455 - val_loss: 0.0700
# Epoch 18/100
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0453 - val_loss: 0.0699
# Epoch 19/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0452 - val_loss: 0.0707
# Epoch 20/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0452 - val_loss: 0.0696
# Epoch 21/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0451 - val_loss: 0.0696
# Epoch 22/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0451 - val_loss: 0.0698
# Epoch 23/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0450 - val_loss: 0.0694
# Epoch 24/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0454 - val_loss: 0.0703
# Epoch 25/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0453 - val_loss: 0.0694
# Epoch 26/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0450 - val_loss: 0.0703
# Epoch 27/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0449 - val_loss: 0.0694
# Epoch 28/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0447 - val_loss: 0.0687
# Epoch 29/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0445 - val_loss: 0.0681
# Epoch 30/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0442 - val_loss: 0.0679
# Epoch 31/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0441 - val_loss: 0.0673
# Epoch 32/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0434 - val_loss: 0.0654
# Epoch 33/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0422 - val_loss: 0.0637
# Epoch 34/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0404 - val_loss: 0.0595
# Epoch 35/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0388 - val_loss: 0.0542
# Epoch 36/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0341 - val_loss: 0.0450
# Epoch 37/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0297 - val_loss: 0.0396
# Epoch 38/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0271 - val_loss: 0.0357
# Epoch 39/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0258 - val_loss: 0.0352
# Epoch 40/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0248 - val_loss: 0.0327
# Epoch 41/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0237 - val_loss: 0.0313
# Epoch 42/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0232 - val_loss: 0.0307
# Epoch 43/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0239 - val_loss: 0.0301
# Epoch 44/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0228 - val_loss: 0.0288
# Epoch 45/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0222 - val_loss: 0.0283
# Epoch 46/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0219 - val_loss: 0.0275
# Epoch 47/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0217 - val_loss: 0.0270
# Epoch 48/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0215 - val_loss: 0.0266
# Epoch 49/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0219 - val_loss: 0.0267
# Epoch 50/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0216 - val_loss: 0.0261
# Epoch 51/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0212 - val_loss: 0.0257
# Epoch 52/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0210 - val_loss: 0.0252
# Epoch 53/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0208 - val_loss: 0.0253
# Epoch 54/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0208 - val_loss: 0.0250
# Epoch 55/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0209 - val_loss: 0.0248
# Epoch 56/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0207 - val_loss: 0.0248
# Epoch 57/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0206 - val_loss: 0.0243
# Epoch 58/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0204 - val_loss: 0.0241
# Epoch 59/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0204 - val_loss: 0.0241
# Epoch 60/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0202 - val_loss: 0.0239
# Epoch 61/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0202 - val_loss: 0.0244
# Epoch 62/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0206 - val_loss: 0.0237
# Epoch 63/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0202 - val_loss: 0.0236
# Epoch 64/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0199 - val_loss: 0.0235
# Epoch 65/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0197 - val_loss: 0.0234
# Epoch 66/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0196 - val_loss: 0.0234
# Epoch 67/100
#  - ETA: 0s - loss: 0.0194
# Epoch 68/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0204 - val_loss: 0.0231
# Epoch 69/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0195 - val_loss: 0.0230
# Epoch 70/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0191 - val_loss: 0.0226
# Epoch 71/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0188 - val_loss: 0.0225
# Epoch 72/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0186 - val_loss: 0.0220
# Epoch 73/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0183 - val_loss: 0.0220
# Epoch 74/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0182 - val_loss: 0.0230
# Epoch 75/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0191 - val_loss: 0.0220
# Epoch 76/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0180 - val_loss: 0.0216
# Epoch 77/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0175 - val_loss: 0.0211
# Epoch 78/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0173 - val_loss: 0.0209
# Epoch 79/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0171 - val_loss: 0.0208
# Epoch 80/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0172 - val_loss: 0.0214
# Epoch 81/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0175 - val_loss: 0.0210
# Epoch 82/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0173 - val_loss: 0.0212
# Epoch 83/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0167 - val_loss: 0.0199
# Epoch 84/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0163 - val_loss: 0.0197
# Epoch 85/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0163 - val_loss: 0.0197
# Epoch 86/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0162 - val_loss: 0.0193
# Epoch 87/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0162 - val_loss: 0.0203
# Epoch 88/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0163 - val_loss: 0.0190
# Epoch 89/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0158 - val_loss: 0.0189
# Epoch 90/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0157 - val_loss: 0.0189
# Epoch 91/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0156 - val_loss: 0.0189
# Epoch 92/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0156 - val_loss: 0.0186
# Epoch 93/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0156 - val_loss: 0.0185
# Epoch 94/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0154 - val_loss: 0.0184
# Epoch 95/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0153 - val_loss: 0.0184
# Epoch 96/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0152 - val_loss: 0.0184
# Epoch 97/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0153 - val_loss: 0.0183
# Epoch 98/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0154 - val_loss: 0.0186
# Epoch 99/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0153 - val_loss: 0.0179
# Epoch 100/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0150 - val_loss: 0.0180
# Completed 4 reconstruction and encoding, saved test data to assess performance
# Starting on index: 11
# Epoch 1/100
# 9/9 [==============================] - 0s 42ms/step - loss: 0.8752 - val_loss: 0.6906
# Epoch 2/100
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3992 - val_loss: 0.4624
# Epoch 3/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.2067 - val_loss: 0.4325
# Epoch 4/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.1739 - val_loss: 0.4178
# Epoch 5/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1576 - val_loss: 0.3978
# Epoch 6/100
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1449 - val_loss: 0.3919
# Epoch 7/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1360 - val_loss: 0.3877
# Epoch 8/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1209 - val_loss: 0.3846
# Epoch 9/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0992 - val_loss: 0.3743
# Epoch 10/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0837 - val_loss: 0.3639
# Epoch 11/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0771 - val_loss: 0.3575
# Epoch 12/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0732 - val_loss: 0.3480
# Epoch 13/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0709 - val_loss: 0.3420
# Epoch 14/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0691 - val_loss: 0.3362
# Epoch 15/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0675 - val_loss: 0.3320
# Epoch 16/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0661 - val_loss: 0.3268
# Epoch 17/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0646 - val_loss: 0.3207
# Epoch 18/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0629 - val_loss: 0.3131
# Epoch 19/100
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0614 - val_loss: 0.3050
# Epoch 20/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0591 - val_loss: 0.2949
# Epoch 21/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0569 - val_loss: 0.2860
# Epoch 22/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0548 - val_loss: 0.2792
# Epoch 23/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0534 - val_loss: 0.2732
# Epoch 24/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0517 - val_loss: 0.2680
# Epoch 25/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0504 - val_loss: 0.2635
# Epoch 26/100
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0493 - val_loss: 0.2596
# Epoch 27/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0483 - val_loss: 0.2554
# Epoch 28/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0480 - val_loss: 0.2522
# Epoch 29/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0467 - val_loss: 0.2478
# Epoch 30/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0458 - val_loss: 0.2431
# Epoch 31/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0450 - val_loss: 0.2399
# Epoch 32/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0442 - val_loss: 0.2373
# Epoch 33/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0443 - val_loss: 0.2347
# Epoch 34/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0433 - val_loss: 0.2323
# Epoch 35/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0426 - val_loss: 0.2306
# Epoch 36/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0421 - val_loss: 0.2285
# Epoch 37/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0417 - val_loss: 0.2273
# Epoch 38/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0414 - val_loss: 0.2259
# Epoch 39/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0417 - val_loss: 0.2258
# Epoch 40/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0411 - val_loss: 0.2238
# Epoch 41/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0406 - val_loss: 0.2225
# Epoch 42/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0402 - val_loss: 0.2217
# Epoch 43/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0399 - val_loss: 0.2211
# Epoch 44/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0398 - val_loss: 0.2198
# Epoch 45/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0394 - val_loss: 0.2186
# Epoch 46/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0391 - val_loss: 0.2174
# Epoch 47/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0388 - val_loss: 0.2154
# Epoch 48/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0388 - val_loss: 0.2160
# Epoch 49/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0383 - val_loss: 0.2116
# Epoch 50/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0378 - val_loss: 0.2092
# Epoch 51/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0373 - val_loss: 0.2059
# Epoch 52/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0368 - val_loss: 0.2041
# Epoch 53/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0363 - val_loss: 0.2021
# Epoch 54/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0361 - val_loss: 0.2010
# Epoch 55/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0358 - val_loss: 0.1985
# Epoch 56/100
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0351 - val_loss: 0.1966
# Epoch 57/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0349 - val_loss: 0.1956
# Epoch 58/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0343 - val_loss: 0.1937
# Epoch 59/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0342 - val_loss: 0.1944
# Epoch 60/100
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0347 - val_loss: 0.1937
# Epoch 61/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0334 - val_loss: 0.1909
# Epoch 62/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0327 - val_loss: 0.1904
# Epoch 63/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0325 - val_loss: 0.1892
# Epoch 64/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0319 - val_loss: 0.1883
# Epoch 65/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0315 - val_loss: 0.1876
# Epoch 66/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0313 - val_loss: 0.1872
# Epoch 67/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0309 - val_loss: 0.1859
# Epoch 68/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0306 - val_loss: 0.1858
# Epoch 69/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0307 - val_loss: 0.1855
# Epoch 70/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0304 - val_loss: 0.1837
# Epoch 71/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0300 - val_loss: 0.1851
# Epoch 72/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0299 - val_loss: 0.1844
# Epoch 73/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0295 - val_loss: 0.1833
# Epoch 74/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0293 - val_loss: 0.1828
# Epoch 75/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0291 - val_loss: 0.1825
# Epoch 76/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0291 - val_loss: 0.1821
# Epoch 77/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0287 - val_loss: 0.1816
# Epoch 78/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0285 - val_loss: 0.1807
# Epoch 79/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0288 - val_loss: 0.1797
# Epoch 80/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0282 - val_loss: 0.1792
# Epoch 81/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0279 - val_loss: 0.1801
# Epoch 82/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0277 - val_loss: 0.1797
# Epoch 83/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0277 - val_loss: 0.1793
# Epoch 84/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0274 - val_loss: 0.1780
# Epoch 85/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0274 - val_loss: 0.1789
# Epoch 86/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0273 - val_loss: 0.1780
# Epoch 87/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0271 - val_loss: 0.1773
# Epoch 88/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0270 - val_loss: 0.1766
# Epoch 89/100
#  - 0s 35ms/step - loss: 0.0268 - val_loss: 0.1766
# Epoch 90/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0268 - val_loss: 0.1760
# Epoch 91/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0266 - val_loss: 0.1757
# Epoch 92/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0264 - val_loss: 0.1751
# Epoch 93/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0262 - val_loss: 0.1740
# Epoch 94/100
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0259 - val_loss: 0.1743
# Epoch 95/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0260 - val_loss: 0.1731
# Epoch 96/100
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0258 - val_loss: 0.1737
# Epoch 97/100
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0258 - val_loss: 0.1724
# Epoch 98/100
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0254 - val_loss: 0.1725
# Epoch 99/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0254 - val_loss: 0.1727
# Epoch 100/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0253 - val_loss: 0.1723
# Completed 11 reconstruction and encoding, saved test data to assess performance
