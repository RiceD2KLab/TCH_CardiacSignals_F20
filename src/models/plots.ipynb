# %%
# %cd C:\Users\ksrai\Projects\TCH_CardiacSignals_F20\TCH_CardiacSignals_F20\
# Out:
# C:\Users\ksrai\Projects\TCH_CardiacSignals_F20\TCH_CardiacSignals_F20

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
original = np.load("Working_Data/Normalized_Fixed_Dim_HBs_Idx16.npy")
reconstructed = np.load("Working_Data/reconstructed_cdae_100d_Idx16.npy")

# %%
from src.utils.plotting_utils import *
import seaborn as sns
data = original[1,:,0]

# plt.plot(data[:200], c='red')
plt.plot(reconstructed[4575,:,0], c='red')

# %%
SMALLER_SIZE = 10
MED_SIZE = 12
BIG_SIZE = 18

# plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MED_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MED_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALLER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALLER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MED_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIG_SIZE)  # fontsize of the figure title
# set_font_size()
plt.rcParams['figure.dpi'] = 500
plt.title("Original vs. Reconstructed Heartbeat for Lead 1 for Patient 16")
set_font_size()
plt.plot(reconstructed[1,850:950,0], label = 'Reconstructed', c='Blue')
plt.plot(original[1,850:950,0], label ='original', c='Red')
plt.legend(loc='lower right')
# plt.xlabel("")
plt.savefig("Working_Data/Visualizations/hbcompare.png")

# %%
set_font_size()
plt.rcParams['figure.dpi'] = 500
plt.title("Original vs. Reconstructed Heartbeat for Lead 1")
set_font_size()
plt.plot(reconstructed[1,850:950,0], label = 'Reconstructed', c='Blue')
plt.plot(original[1,850:950,0], label ='original', c='Red', alpha = 0.6, linewidth=2)
plt.legend(loc='lower right')
# plt.xlabel("")
plt.savefig("Working_Data/Visualizations/hbcompare3_pat16.png")

# %%
set_font_size()
plt.rcParams['figure.dpi'] = 500
plt.title("Original vs. Reconstructed Heartbeat for Lead 1")
set_font_size()
plt.plot(reconstructed[1,650:950,0], label = 'Reconstructed', c='Blue')
plt.plot(original[1,650:950,0], label ='original', c='Red', alpha = 0.6, linewidth=2)
plt.legend(loc='lower right')
# plt.xlabel("")
plt.savefig("Working_Data/Visualizations/hbcompare2_pat16.png")

# %%
plt.figure(figsize=(20,10))
plt.subplot(4,1,1)
plt.axis('off')
plt.plot(original[1,:,0], c='red')
plt.subplot(4,1,2)
plt.axis('off')
plt.plot(original[1,:,1], c='red')
plt.subplot(4,1,3)
plt.axis('off')
plt.plot(original[1,:,2], c='red')
plt.subplot(4,1,4)
plt.axis('off')
plt.plot(original[1,:,3], c='red')
plt.savefig("Working_Data/Visualizations/original.pdf", bbox_inches='tight')

# %%
plt.figure(figsize=(20,10))
plt.subplot(4,1,1)
plt.axis('off')
plt.plot(reconstructed[1,:,0], c='red')
plt.subplot(4,1,2)
plt.axis('off')
plt.plot(reconstructed[1,:,1], c='red')
plt.subplot(4,1,3)
plt.axis('off')
plt.plot(reconstructed[1,:,2], c='red')
plt.subplot(4,1,4)
plt.axis('off')
plt.plot(reconstructed[1,:,3], c='red')
plt.savefig("Working_Data/Visualizations/reconstructed.pdf", bbox_inches='tight')

# %%
reduced = np.load("Working_Data/reduced_cdae_100d_Idx16.npy")

# %%
plt.figure(figsize=(20,10))
plt.subplot(4,1,1)
plt.axis('off')
plt.plot(reduced[2,:], c='red')
# plt.subplot(4,1,2)
# plt.axis('off')
# plt.plot(reconstructed[1,:,1], c='red')
# plt.subplot(4,1,3)
# plt.axis('off')
# plt.plot(reconstructed[1,:,2], c='red')
# plt.subplot(4,1,4)
# plt.axis('off')
# plt.plot(reconstructed[1,:,3], c='red')
plt.savefig("Working_Data/Visualizations/reduced.pdf", bbox_inches='tight')

# %%
set_font_size()
plt.rcParams['figure.dpi'] = 500
plt.title("Normal Heartbeat")
set_font_size()
plt.plot(original[1,850:950,0], c='Blue')

plt.legend(loc='lower right')
# plt.xlabel("")
plt.savefig("Working_Data/Visualizations/oghbcompare1_pat16.pdf")
# Out:
# No handles with labels found to put in legend.

# %%
set_font_size()
plt.rcParams['figure.dpi'] = 500
plt.title("Heartbeat Near Cardiac Arrest")
set_font_size()
plt.plot(original[4575,850:950,0], label ='Abnormal Heartbeat', c='Red', alpha = 0.6, linewidth=2)
plt.savefig("Working_Data/Visualizations/oghbcompare2_pat16.pdf")
